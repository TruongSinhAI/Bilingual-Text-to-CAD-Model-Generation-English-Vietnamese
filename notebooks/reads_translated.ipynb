# %%
import json
from datasets import load_dataset, Dataset, DatasetDict 
import pandas as pd

# %%
dataset = load_dataset("TruongSinhAI/deepcad_prompt_json")

merged_df = pd.concat([
    dataset["train"].to_pandas(),
    dataset["validation"].to_pandas(),
    dataset["test"].to_pandas()
], ignore_index=True)

# Calculate the split size (same length for each)
split_size = len(merged_df) // 3

# Create new train, validation, and test datasets
new_train_df = merged_df.iloc[:split_size]
new_val_df = merged_df.iloc[split_size:2*split_size]
new_test_df = merged_df.iloc[2*split_size:]

#Convert back to datasets
new_train_ds = Dataset.from_pandas(new_train_df)
new_val_ds = Dataset.from_pandas(new_val_df)
new_test_ds = Dataset.from_pandas(new_test_df)

new_dataset = DatasetDict({
    'part_1': new_train_ds,
    'part_2': new_val_ds,
    'part_3': new_test_ds
})

new_dataset
# Out:
# DatasetDict({
#     part_1: Dataset({
#         features: ['uid', 'input', 'output', 'instruction'],
#         num_rows: 57840
#     })
#     part_2: Dataset({
#         features: ['uid', 'input', 'output', 'instruction'],
#         num_rows: 57840
#     })
#     part_3: Dataset({
#         features: ['uid', 'input', 'output', 'instruction'],
#         num_rows: 57841
#     })
# })

# %%
def read_jsonl(path):
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)

    return data

# %%
data_part3 = read_jsonl("./part1_/translation_0.json")
data_part2 = read_jsonl("./part1_2/translation_0.json")

# %%
save = {
    'uid': [],
    'input':[],
    'input_vi':[],
    'output':[],
}
for data in new_dataset['part_1']:
    save['uid'].append(data['uid'])
    save['input'].append(data['input'])
    try:
        save['input_vi'].append(indexs[data['uid']])
    except:
         save['input_vi'].append('')
    save['output'].append(data['output'])

# %%
save['input_vi'].index('')
# Out:
# 47082

# %%
new = Dataset.from_dict(save)

# %%
counting = 0
# lada = []
for data in new:
    if data['input_vi'] == '':
        counting += 1
        # lada.append(data)
counting
# Out:
# 0

# %%
trans = [
  "Tạo hệ tọa độ mới với góc Euler (0.0, 0.0, -90.0) và vectơ tịnh tiến (0.0, 0.0308, 0.0) cho Part 1, một tấm kim loại hình chữ nhật có lỗ tròn ở giữa.\n\nTrên mặt phẳng được xác định bởi hệ tọa độ, tạo một bản phác thảo bao gồm một mặt (Mặt 1) với năm vòng lặp: Vòng lặp 1 (Hình chữ nhật), Vòng lặp 2 (Hình tròn), Vòng lặp 3 (Hình dạng phức tạp với cung và đường thẳng), Vòng lặp 4 (Hình tròn), và Vòng lặp 5 (Hình tròn).\n\n- Vòng lặp 1 (Hình chữ nhật): Bốn đường thẳng với điểm bắt đầu và điểm kết thúc như sau: [Đường 1: (0.0, 0.0), (0.75, 0.0)], [Đường 2: (0.75, 0.0), (0.75, 0.347)], [Đường 3: (0.75, 0.347), (0.0, 0.347)], [Đường 4: (0.0, 0.347), (0.0, 0.0)]\n- Vòng lặp 2 (Hình tròn): Tâm tại (0.1253, 0.1735), Bán kính 0.0193\n- Vòng lặp 3 (Hình dạng phức tạp với cung và đường thẳng)\n  + Cung 1: Điểm bắt đầu (0.1812, 0.1321), Điểm giữa (0.1869, 0.1184), Điểm kết thúc (0.2005, 0.1128)\n  + Đường 1: Điểm bắt đầu (0.2005, 0.1128), Điểm kết thúc (0.3393, 0.1128)\n  + Cung 2: Điểm bắt đầu (0.3393, 0.1128), Điểm giữa (0.353, 0.1184), Điểm kết thúc (0.3586, 0.1321)\n  + Đường 2: Điểm bắt đầu (0.3586, 0.1321), Điểm kết thúc (0.3586, 0.215)\n  + Cung 3: Điểm bắt đầu (0.3586, 0.215), Điểm giữa (0.353, 0.2286), Điểm kết thúc (0.3393, 0.2343)\n  + Đường 3: Điểm bắt đầu (0.3393, 0.2343), Điểm kết thúc (0.2005, 0.2343)\n  + Cung 4: Điểm bắt đầu (0.2005, 0.2343), Điểm giữa (0.1869, 0.2286), Điểm kết thúc (0.1812, 0.215)\n  + Đường 4: Điểm bắt đầu (0.1812, 0.215), Điểm kết thúc (0.1812, 0.1321)\n- Vòng lặp 4 (Hình tròn): Tâm tại (0.4145, 0.1735), Bán kính 0.0193\n- Vòng lặp 5 (Hình tròn): Tâm tại (0.5774, 0.1735), Bán kính 0.0771\n\nPhóng to toàn bộ bản phác thảo theo hệ số 0.75 và sau đó đùn bản phác thảo theo hướng pháp tuyến 0.0308 đơn vị, với kích thước cuối cùng: Chiều dài 0.75 đơn vị, Chiều rộng 0.030848329048843194 đơn vị, và Chiều cao 0.75 đơn vị.",
  "Tạo phần đầu tiên của mô hình CAD, một lăng trụ chữ nhật có mặt trên và mặt dưới phẳng. Bắt đầu bằng cách thiết lập một hệ tọa độ mới với các góc Euler [0.0, 0.0, -90.0] và vectơ tịnh tiến [0.0, 0.0333, 0.0].\n\nTiếp theo, tạo bản phác thảo 2D trên mặt phẳng X-Y của hệ tọa độ. Vẽ một hình chữ nhật với bốn đường thẳng: đường 1 bắt đầu tại [0.0, 0.0] và kết thúc tại [0.75, 0.0], đường 2 bắt đầu tại [0.75, 0.0] và kết thúc tại [0.75, 0.075], đường 3 bắt đầu tại [0.75, 0.075] và kết thúc tại [0.0, 0.075], đường 4 bắt đầu tại [0.0, 0.075] và kết thúc tại [0.0, 0.0].\n\nPhóng to bản phác thảo 2D theo hệ số 0.75. Sau đó, chuyển đổi bản phác thảo 2D thành bản phác thảo 3D bằng cách thực hiện phép biến đổi quay với các góc Euler và phép tịnh tiến sử dụng vectơ tịnh tiến.\n\nCuối cùng, đùn bản phác thảo 3D theo hướng pháp tuyến với độ sâu 0.0333 đơn vị, tạo ra phần đầu tiên của mô hình CAD. Phóng to bản phác thảo theo hệ số 0.75 và tạo một khối rắn mới cho thao tác này. Phần này có các kích thước sau: chiều cao 0.75 đơn vị, chiều rộng 0.0333 đơn vị và chiều dài 0.75 đơn vị.",
  "Tạo mô hình CAD của một vật thể tròn có lỗ ở giữa, giống như một bánh răng hoặc bánh xe, tuân thủ các hướng dẫn chi tiết sau. Bắt đầu bằng cách tạo một hệ tọa độ mới với góc Euler [0.0, 0.0, 0.0] và vectơ tịnh tiến [0.0215, 0.0, 0.0]. Sau đó, vẽ một bản phác thảo 2D trên mặt phẳng X-Y của hệ tọa độ này.\n\nCác vòng lặp của bản phác thảo sẽ bao gồm nhiều đường cong, bao gồm cung và đường thẳng, xác định hình dạng phức tạp của bánh răng.\n\n1.1 Vòng lặp\\\\_1 - Đường cong (cung\\\\_1, đường\\\\_1, cung\\\\_2, đường\\\\_2, cung\\\\_3, đường\\\\_3, cung\\\\_4, đường\\\\_4, cung\\\\_5, đường\\\\_5, cung\\\\_6, đường\\\\_6)\n\n1.1.1 cung\\\\_1 - Điểm bắt đầu [0.0, 0.4939], Điểm giữa [0.0287, 0.1812], Điểm kết thúc [0.2852, 0.0]\n\n1.1.2 đường\\\\_1 - Điểm bắt đầu [0.2852, 0.0], Điểm kết thúc [0.3061, 0.1131]\n\n1.1.3 cung\\\\_2 - Điểm bắt đầu [0.3061, 0.1131], Điểm giữa [0.3535, 0.1087], Điểm kết thúc [0.4009, 0.1131]\n\n1.1.4 đường\\\\_2 - Điểm bắt đầu [0.4009, 0.1131], Điểm kết thúc [0.4218, 0.0]\n\n1.1.5 cung\\\\_3 - Điểm bắt đầu [0.4218, 0.0], Điểm giữa [0.6783, 0.1812], Điểm kết thúc [0.707, 0.4939]\n\n1.1.6 đường\\\\_3 - Điểm bắt đầu [0.707, 0.4939], Điểm kết thúc [0.5986, 0.4555]\n\n1.1.7 cung\\\\_4 - Điểm bắt đầu [0.5986, 0.4555], Điểm giữa [0.5787, 0.4987], Điểm kết thúc [0.5512, 0.5376]\n\n1.1.8 đường\\\\_4 - Điểm bắt đầu [0.5512, 0.5376], Điểm kết thúc [0.6386, 0.6123]\n\n1.1.9 cung\\\\_5 - Điểm bắt đầu [0.6386, 0.6123], Điểm giữa [0.3535, 0.7437], Điểm kết thúc [0.0683, 0.6123]\n\n1.1.10 đường\\\\_5 - Điểm bắt đầu [0.0683, 0.6123], Điểm kết thúc [0.1558, 0.5376]\n\n1.1.11 cung\\\\_6 - Điểm bắt đầu [0.1558, 0.5376], Điểm giữa [0.1283, 0.4987], Điểm kết thúc [0.1084, 0.4555]\n\n1.1.12 đường\\\\_6 - Điểm bắt đầu [0.1084, 0.4555], Điểm kết thúc [0.0, 0.4939]\n\nTiếp theo, tạo bốn hình tròn (hình tròn\\\\_1, hình tròn\\\\_2, hình tròn\\\\_3, hình tròn\\\\_4) với tâm và bán kính được đề cập trong hướng dẫn.\n\n1.2 Phóng to: Phóng to bản phác thảo 2D theo hệ số 0.7437.\n\n1.3 Biến đổi bản phác thảo: Biến đổi bản phác thảo 2D đã phóng to thành bản phác thảo 3D sử dụng các góc euler và vectơ tịnh tiến được chỉ định.\n\n1.4 Đùn bản phác thảo 3D 0.020 đơn vị theo hướng pháp tuyến và 0 đơn vị theo hướng ngược lại, hoàn thành mô hình CAD cho phần 1.",
  "Tạo phần đầu tiên của mô hình CAD, một vật thể kim loại cong, lặp và xoắn với trung tâm rỗng. Bắt đầu bằng cách thiết lập một hệ tọa độ mới với góc Euler (-90.0, 0.0, -90.0) và vectơ tịnh tiến (0.0, 0.0, 0.0).\n\nTiếp theo, vẽ một bản phác thảo 2D trên một mặt phẳng sử dụng hệ tọa độ này. Bản phác thảo bao gồm hai mặt, mặt\\\\_1 và mặt\\\\_2. Mặt\\\\_1 bao gồm hai vòng lặp, vòng lặp\\\\_1 và vòng lặp\\\\_2.\n\n- **Vòng lặp 1**\n    - Đường 1: Điểm bắt đầu (0.2352, 0.0), Điểm kết thúc (0.5148, 0.0)\n    - Cung 1: Điểm bắt đầu (0.5148, 0.0), Điểm giữa (0.75, 0.2352), Điểm kết thúc (0.5148, 0.4703)\n    - Đường 2: Điểm bắt đầu (0.5148, 0.4703), Điểm kết thúc (0.2352, 0.4703)\n    - Cung 2: Điểm bắt đầu (0.2352, 0.4703), Điểm giữa (0.0, 0.2352), Điểm kết thúc (0.2352, 0.0)\n\n- **Vòng lặp 2**\n    - Đường 1: Điểm bắt đầu (0.2352, 0.0232), Điểm kết thúc (0.5148, 0.0232)\n    - Cung 1: Điểm bắt đầu (0.5148, 0.0232), Điểm giữa (0.7268, 0.2352), Điểm kết thúc (0.5148, 0.4471)\n    - Đường 2: Điểm bắt đầu (0.5148, 0.4471), Điểm kết thúc (0.2352, 0.4471)\n    - Cung 2: Điểm bắt đầu (0.2352, 0.4471), Điểm giữa (0.0232, 0.2352), Điểm kết thúc (0.2352, 0.0232)\n\nBây giờ, đùn bản phác thảo với độ sâu 0.0543 về phía pháp tuyến và 0.0 ngược với pháp tuyến. Áp dụng tỷ lệ bản phác thảo là 0.75 và tạo một khối rắn mới là kết quả của việc đùn.\n\nPhần đầu tiên của mô hình CAD có các kích thước sau: chiều dài 0.0543, chiều rộng 0.75 và chiều cao 0.75.",
  "Bắt đầu bằng cách tạo một hệ tọa độ mới cho `part_1` với góc Euler [0.0, 0.0, -90.0] và vectơ tịnh tiến [0.0, 0.75, 0.0].\n\nTiếp theo, tạo bản phác thảo 2D trên mặt phẳng XY của hệ tọa độ với một vòng lặp kín bao gồm sáu đoạn thẳng: line\\\\_1, line\\\\_2, line\\\\_3, line\\\\_4, line\\\\_5 và line\\\\_6. Các đường thẳng có điểm bắt đầu và kết thúc như được chỉ định trong hướng dẫn.\n\nÁp dụng phép biến đổi tỷ lệ đồng nhất với hệ số tỷ lệ 0.75 (0.7499999999999998 theo JSON) cho bản phác thảo.\n\nBiến đổi bản phác thảo 2D đã được tỷ lệ thành bản phác thảo 3D bằng cách quay nó quanh trục Z -90 độ và tịnh tiến nó bằng vectơ được chỉ định [0.0, 0.75, 0.0].\n\nĐùn bản phác thảo theo hướng pháp tuyến một khoảng cách 0.75 đơn vị (0.7499999999999998 theo JSON). Điều này tạo thành hình dạng 3D cuối cùng cho `part_1` với các kích thước sau: chiều cao 0.75 đơn vị, chiều rộng 0.75 đơn vị và chiều dài 0.75 đơn vị.",
  "**Phần 1: Lăng trụ chữ nhật ba chiều với lỗ hình trụ**\n\nTạo hệ tọa độ mới với các tham số sau:\n- Góc Euler: (0.0, 0.0, 0.0)\n- Vectơ tịnh tiến: (0.0, 0.0, 0.0)\n\nĐối với bản phác thảo trên mặt phẳng X-Y, vẽ một hình chữ nhật với các đường thẳng sau:\n- Đường 1: (0.0, 0.0) đến (0.75, 0.0)\n- Đường 2: (0.75, 0.0) đến (0.75, 0.5893)\n- Đường 3: (0.75, 0.5893) đến (0.0, 0.5893)\n- Đường 4: (0.0, 0.5893) đến (0.0, 0.0)\n\nTrên cùng mặt phẳng phác thảo, tạo năm hình tròn với tâm và bán kính sau:\n- Vòng lặp 2: (0.4821, 0.2946), bán kính: 0.2518\n- Vòng lặp 3: (0.2679, 0.0804), bán kính: 0.0161\n- Vòng lặp 4: (0.2679, 0.5089), bán kính: 0.0161\n- Vòng lặp 5: (0.6964, 0.0804), bán kính: 0.0161\n- Vòng lặp 6: (0.6964, 0.5089), bán kính: 0.0161\n\nPhóng to bản phác thảo theo hệ số 0.75 và biến đổi nó thành bản phác thảo 3D sử dụng hệ tọa độ đã xác định. Đùn bản phác thảo 2D với các thuộc tính sau:\n- Độ sâu đùn về phía pháp tuyến: 0.0321\n- Độ sâu đùn ngược hướng pháp tuyến: 0.0\n- Tỷ lệ bản phác thảo: 0.75\n- Thao tác: Tạo một khối rắn mới\n\n**Phần 2: Tấm kim loại hình chữ nhật có lỗ**\n\nTạo hệ tọa độ mới với các tham số sau:\n- Góc Euler: (90.0, 0.0, -90.0)\n- Vectơ tịnh tiến: (0.0, 0.5893, 0.0)\n\nĐối với bản phác thảo trên mặt phẳng Y-Z, vẽ một hình chữ nhật với các đường thẳng sau:\n- Đường 1: (0.0, 0.0) đến (0.5893, 0.0)\n- Đường 2: (0.5893, 0.0) đến (0.5893, 0.0321)\n- Đường 3: (0.5893, 0.0321) đến (0.0, 0.0321)\n- Đường 4: (0.0, 0.0321) đến (0.0, 0.0)\n\nĐối với cùng mặt phẳng phác thảo, vẽ một hình chữ nhật khác với các đường thẳng sau:\n- Đường 1: (0.0, 0.0321) đến (0.5893, 0.0321)\n- Đường 2: (0.5893, 0.0321) đến (0.5893, 0.2143)\n- Đường 3: (0.5893, 0.2143) đến (0.0, 0.2143)\n- Đường 4: (0.0, 0.2143) đến (0.0, 0.0321)\n\nĐối với cùng mặt phẳng phác thảo, tạo hai hình tròn với tâm và bán kính sau:\n- Vòng lặp 2: (0.1473, 0.1071), bán kính: 0.0289\n- Vòng lặp 3: (0.442, 0.1071), bán kính: 0.0289\n\nPhóng to bản phác thảo theo hệ số 0.5893 và biến đổi nó thành bản phác thảo 3D sử dụng hệ tọa độ đã xác định. Đùn bản phác thảo 2D với các thuộc tính sau:\n- Độ sâu đùn về phía pháp tuyến: 0.0\n- Độ sâu đùn ngược hướng pháp tuyến: 0.0321\n- Tỷ lệ bản phác thảo: 0.5893\n- Thao tác: Nối khối rắn hiện có với khối hiện tại\n\n**Phần 3: Lăng trụ chữ nhật ba chiều với đáy hình tam giác**\n\nTạo hệ tọa độ mới với các tham số sau:\n- Góc Euler: (0.0, 0.0, -90.0)\n- Vectơ tịnh tiến: (0.0321, 0.0, 0.0321)\n\nĐối với bản phác thảo, vẽ một hình chữ nhật trên mặt phẳng X-Z với các đường thẳng sau:\n- Đường 1: (0.0, 0.0) đến (0.1365, 0.0)\n- Đường 2: (0'",
  "Tạo một vật thể hình chữ nhật dài, mỏng, có mặt trên và dưới phẳng, mặt trên hơi thuôn và một đường thẳng đứng ở giữa. Bắt đầu bằng cách thiết lập hệ tọa độ mới với các góc Euler (0.0, 0.0, 0.0) và vectơ tịnh tiến (0.0, 0.0, 0.0).\n\nTiếp theo, tạo bản phác thảo 2D trên một mặt phẳng được xác định bởi hệ tọa độ. Bản phác thảo sẽ có một mặt (face\\\\_1) với một vòng lặp (loop\\\\_1) chứa bốn đường thẳng: line\\\\_1, line\\\\_2, line\\\\_3 và line\\\\_4. Các đường thẳng được bố trí như sau:\n- line\\\\_1: Điểm bắt đầu (0.0, 0.0), Điểm kết thúc (0.15, 0.0)\n- line\\\\_2: Điểm bắt đầu (0.15, 0.0), Điểm kết thúc (0.15, 0.0187)\n- line\\\\_3: Điểm bắt đầu (0.15, 0.0187), Điểm kết thúc (0.0, 0.0187)\n- line\\\\_4: Điểm bắt đầu (0.0, 0.0187), Điểm kết thúc (0.0, 0.0)\n\nPhóng to bản phác thảo 2D bằng cách sử dụng tham số tỷ lệ 0.15 và biến đổi nó thành bản phác thảo 3D sử dụng các góc euler và vectơ tịnh tiến được xác định trong hệ tọa độ.\n\nĐùn bản phác thảo 3D với độ sâu đùn 0.75 đơn vị theo hướng pháp tuyến và 0.0 đơn vị theo hướng ngược lại của pháp tuyến. Thao tác này sẽ tạo ra mô hình 3D của vật thể hình chữ nhật dài, mỏng, có mặt trên và dưới phẳng, mặt trên hơi thuôn và một đường thẳng đứng ở giữa.",
  "Tạo phần đầu tiên của mô hình CAD, một lăng trụ chữ nhật có lỗ hình trụ ở giữa. Bắt đầu bằng cách tạo hệ tọa độ mới với các góc Euler (0.0, 0.0, 0.0) và vectơ tịnh tiến (0.0, 0.0, 0.0).\n\nChuyển sang chế độ phác thảo và vẽ bản phác thảo 2D trên mặt phẳng X-Y của hệ tọa độ. Tạo hình chữ nhật bao gồm bốn cạnh thẳng: đường 1 (Điểm bắt đầu: (0.0, 0.0), Điểm kết thúc: (0.75, 0.0)); đường 2 (Điểm bắt đầu: (0.75, 0.0), Điểm kết thúc: (0.75, 0.375)); đường 3 (Điểm bắt đầu: (0.75, 0.375), Điểm kết thúc: (0.0, 0.375)); đường 4 (Điểm bắt đầu: (0.0, 0.375), Điểm kết thúc: (0.0, 0.0)).\n\nBây giờ tạo hình tròn có tâm tại (0.1875, 0.1875) và bán kính 0.0676. Áp dụng hệ số tỷ lệ 0.75 cho toàn bộ bản phác thảo. Sử dụng các góc Euler và vectơ tịnh tiến được chỉ định để biến đổi bản phác thảo 2D đã được tỷ lệ thành 3D.\n\nĐùn bản phác thảo 2D dọc theo trục Z đến độ sâu 0.25 đơn vị. Hình dạng cuối cùng là một lăng trụ chữ nhật có lỗ hình trụ ở giữa, với chiều dài, chiều rộng và chiều cao lần lượt là 0.75, 0.75 và 0.25 đơn vị (bao gồm độ sâu đùn).",
  "Tạo phần đầu tiên của mô hình CAD, một lăng trụ chữ nhật dài với đầu hơi thuôn. Bắt đầu bằng cách thiết lập một hệ tọa độ mới với góc Euler (0.0, 0.0, 0.0) và vectơ tịnh tiến (0.0, 0.0, 0.0).\n\nTiếp theo, tạo bản phác thảo 2D trên mặt phẳng X-Y của hệ tọa độ, bao gồm hai vòng lặp với mỗi vòng có bốn đường thẳng. Vòng lặp 1 có kích thước từ [0.0, 0.0] đến [0.0625, 0.0], [0.0625, 0.0] đến [0.0625, 0.0625], [0.0625, 0.0625] đến [0.0, 0.0625], và [0.0, 0.0625] đến [0.0, 0.0]. Vòng lặp 2 có kích thước từ [0.0039, 0.0039] đến [0.0586, 0.0039], [0.0586, 0.0039] đến [0.0586, 0.0586], [0.0586, 0.0586] đến [0.0039, 0.0586], và [0.0039, 0.0586] đến [0.0039, 0.0039].\n\nPhóng to bản phác thảo bằng cách sử dụng tham số tỷ lệ sketch\\\\_scale, được đặt là 0.0625. Biến đổi bản phác thảo 2D đã được tỷ lệ thành bản phác thảo 3D sử dụng góc Euler và vectơ tịnh tiến từ hệ tọa độ, và đùn bản phác thảo 3D dọc theo pháp tuyến theo hướng Z dương 0.75 đơn vị để tạo khối rắn 3D dựa trên bản phác thảo và tỷ lệ.\n\nHợp nhất khối rắn 3D thu được với bất kỳ khối rắn nào trước đó. Phần này có các kích thước sau: chiều dài 0.0625 đơn vị, chiều rộng 0.0625 đơn vị và chiều cao 0.7500000000000001 đơn vị.",
  "Tạo một đường thẳng dài, mỏng, thẳng là phần đầu tiên của mô hình CAD. Bắt đầu bằng cách thiết lập hệ tọa độ mới với góc Euler (0.0, 0.0, 0.0) và vectơ tịnh tiến (0.0, 0.0, 0.0).\n\nĐối với bản phác thảo, tạo một mặt với một vòng lặp duy nhất bao gồm bốn đường thẳng. Vòng lặp này, được gắn nhãn Vòng lặp 1, có bốn đường thẳng sau:\n\n1. Đường 1: Vẽ đường thẳng từ (0.0, 0.0) đến (0.0192, 0.0).\n2. Đường 2: Vẽ đường thẳng từ (0.0192, 0.0) đến (0.0192, 0.75).\n3. Đường 3: Vẽ đường thẳng từ (0.0192, 0.75) đến (0.0, 0.75).\n4. Đường 4: Vẽ đường thẳng từ (0.0, 0.75) đến (0.0, 0.0).\n\nBây giờ, đùn bản phác thảo dọc theo hướng pháp tuyến 0.0096 đơn vị, không có đùn theo hướng ngược lại. Phóng to bản phác thảo theo hệ số 0.75 trước khi đùn và tạo một khối rắn mới cho thao tác này.\n\nPhần đầu tiên của mô hình CAD có các kích thước sau: chiều dài 0.75 đơn vị, chiều rộng 0.75 đơn vị và chiều cao xấp xỉ 0.009615 đơn vị.",
  "Tạo phần đầu tiên của mô hình CAD, một lăng trụ chữ nhật có một phần cắt hình tam giác trên một trong các mặt của nó. Bắt đầu bằng cách thiết lập hệ tọa độ mới với các góc Euler (0.0, 0.0, 0.0) và vectơ tịnh tiến (0.0, 0.0, 0.0).\n\nTiếp theo, tạo bản phác thảo trên mặt phẳng được xác định bởi hệ tọa độ. Bản phác thảo chứa một mặt duy nhất (face\\\\_1) với một vòng lặp duy nhất (loop\\\\_1) được tạo thành từ bốn đường thẳng (line\\\\_1 đến line\\\\_4):\n\n- line\\\\_1: Điểm bắt đầu = (0.0, 0.0), Điểm kết thúc = (0.75, 0.0)\n- line\\\\_2: Điểm bắt đầu = (0.75, 0.0), Điểm kết thúc = (0.75, 0.1125)\n- line\\\\_3: Điểm bắt đầu = (0.75, 0.1125), Điểm kết thúc = (0.0, 0.1125)\n- line\\\\_4: Điểm bắt đầu = (0.0, 0.1125), Điểm kết thúc = (0.0, 0.0)\n\nĐùn bản phác thảo 2D để tạo mô hình 3D với các tham số được chỉ định:\n\n- extrude\\\\_depth\\\\_towards\\\\_normal = 0.0031\n- extrude\\\\_depth\\\\_opposite\\\\_normal = 0.0\n- sketch\\\\_scale = 0.75\n\nHình dạng cuối cùng có kích thước: chiều dài 0.7499999999999999 đơn vị, chiều rộng 0.7499999999999999 đơn vị và chiều cao 0.0031249999999999997 đơn vị. Phần cắt hình tam giác trên một trong các mặt được thực hiện bằng cách đặt giá trị extrude\\\\_depth\\\\_towards\\\\_normal.",
  "Xây dựng phần đầu tiên của mô hình CAD, một vật thể hình trụ có đầu thuôn. Bắt đầu bằng cách tạo hệ tọa độ mới với các góc Euler (0.0, 0.0, 0.0) và vectơ tịnh tiến (0.0, 0.0, 0.0).\n\nĐối với bản phác thảo, tạo một mặt và vẽ một hình tròn có tâm tại (0.0729, 0.0729) và bán kính 0.0729. Vòng lặp của bản phác thảo bao gồm một hình tròn, là vòng kín.\n\nĐùn bản phác thảo một khoảng cách 0.75 về phía pháp tuyến và 0.0 theo hướng ngược lại của pháp tuyến. Phóng to bản phác thảo theo hệ số 0.1458, tạo một khối rắn mới.\n\nPhần đầu tiên của mô hình CAD có các kích thước sau: chiều cao 0.1458, chiều rộng 0.1458 và chiều dài 0.75.\n\nXây dựng phần thứ hai của mô hình CAD, một hình trụ có mặt trên và dưới hơi thuôn. Thiết lập hệ tọa độ mới với các góc Euler (0.0, 0.0, 0.0) và vectơ tịnh tiến (0.0104, 0.0104, 0.75).\n\nTạo một mặt và phác thảo hình tròn có tâm tại (0.0625, 0.0625) và bán kính 0.0625. Vòng lặp của bản phác thảo bao gồm một hình tròn, là vòng kín.\n\nĐùn bản phác thảo một khoảng cách 0.0 về phía pháp tuyến và 0.625 theo hướng ngược lại của pháp tuyến. Phóng to bản phác thảo theo hệ số 0.125, cắt vào khối hiện có. Hình dạng cuối cùng sẽ là một hình trụ có mặt trên và dưới hơi thuôn.\n\nPhần thứ hai của mô hình CAD có các kích thước sau: chiều cao 0.125, chiều rộng 0.125 và chiều dài 0.625.\n\nHình dạng cuối cùng có các kích thước sau: chiều cao 0.75, chiều rộng 0.1458 và chiều dài 0.1458.",
  "Tạo phần đầu tiên của mô hình CAD, một lăng trụ chữ nhật có lỗ hình trụ. Bắt đầu bằng cách thiết lập hệ tọa độ mới với góc Euler [0.0, 0.0, 0.0] và vectơ tịnh tiến [0.0, 0.0, 0.0].\n\nTiếp theo, tạo bản phác thảo trên mặt phẳng X-Y của hệ tọa độ. Bản phác thảo bao gồm ba vòng lặp và một mặt. Vòng lặp 1 phác thảo lăng trụ chữ nhật, trong khi Vòng lặp 2 và Vòng lặp 3 tạo ra lỗ hình trụ. Vòng lặp 1 được tạo thành bởi bốn đường thẳng, mỗi đường nối từ gốc tọa độ (0,0) đến (0.3462, 0), (0.3462,0.75), (0,0.75) và quay trở lại gốc tọa độ (0,0). Vòng lặp 2 xác định lỗ hình trụ bằng một hình tròn có tâm tại (0.1731,0.2019) với bán kính 0.0865. Vòng lặp 3 xác định cạnh trong của lỗ hình trụ bằng một hình tròn có tâm tại (0.1731,0.6779) với bán kính 0.0144.\n\nBây giờ, phóng to toàn bộ bản phác thảo 2D theo hệ số 0.75 và đùn bản phác thảo dọc theo hướng pháp tuyến với độ sâu 0.0577, tạo ra phần đầu tiên của mô hình CAD. Đảm bảo rằng việc đùn là thêm vật liệu và tạo một khối rắn mới.\n\nPhần đầu tiên của mô hình CAD có các kích thước sau: chiều cao 0.057692307692307696 đơn vị, chiều rộng 0.7499999999999999 đơn vị và chiều dài 0.7499999999999999 đơn vị (bao gồm độ sâu đùn).",
  "Tạo phần đầu tiên của mô hình CAD, một vật thể hình trụ có mặt trên và dưới phẳng, và mặt bên cong. Bắt đầu bằng cách thiết lập hệ tọa độ mới với góc Euler (0.0, 0.0, 0.0) và vectơ tịnh tiến (0.2741, 0.2307, 0.0).\n\nTiếp theo, vẽ mặt đầu tiên của bản phác thảo với một vòng lặp duy nhất chứa một hình tròn, `circle_1`. Xác định vòng lặp với các thuộc tính sau:\n- Tâm: (0.1009, 0.1009)\n- Bán kính: 0.1009\n\nĐùn hình tròn thành hình dạng 3D với các thuộc tính sau:\n- Độ sâu đùn về phía hướng pháp tuyến: 0.0227\n- Độ sâu đùn ngược hướng pháp tuyến: 0.0\n- Tỷ lệ bản phác thảo: 0.2018\n\nKích thước của phần này là:\n- Chiều dài: 0.2018\n- Chiều rộng: 0.2018\n- Chiều cao: 0.0227 (bao gồm độ sâu đùn)",
  "Để tạo phần đầu tiên của mô hình CAD, bắt đầu bằng cách tạo hệ tọa độ mới với góc Euler (0.0, 0.0, -90.0) và vectơ tịnh tiến (0.0, 0.0196, 0.0).\n\nTiếp theo, tạo bản phác thảo mới trên mặt phẳng X-Y của hệ tọa độ. Vẽ bản phác thảo 2D bao gồm bốn đoạn thẳng. Đoạn thẳng thứ nhất bắt đầu tại (0.0, 0.0) và kết thúc tại (0.75, 0.0). Đoạn thẳng thứ hai bắt đầu tại (0.75, 0.0) và kết thúc tại (0.75, 0.589). Đoạn thẳng thứ ba bắt đầu tại (0.75, 0.589) và kết thúc tại (0.0, 0.589). Cuối cùng, đoạn thẳng thứ tư bắt đầu tại (0.0, 0.589) và kết thúc tại điểm bắt đầu của đoạn thẳng thứ nhất, (0.0, 0.0). Bản phác thảo chứa một mặt và một vòng lặp với bốn đoạn thẳng.\n\nSau đó, biến đổi bản phác thảo 2D thành bản phác thảo 3D bằng cách áp dụng phép biến đổi tỷ lệ với hệ số tỷ lệ 0.75, tiếp theo là phép biến đổi đùn dọc theo trục Z với độ sâu đùn 0.0196 đơn vị. Điều này sẽ tạo ra một khối rắn có hình dạng lăng trụ chữ nhật ba chiều.\n\nPhần CAD thu được có các kích thước sau:\n- Chiều dài: 0.75 đơn vị\n- Chiều rộng: 0.0196 đơn vị\n- Chiều cao: 0.75 đơn vị",
  "Tạo phần đầu tiên của mô hình CAD theo hướng dẫn được cung cấp. Bắt đầu bằng cách xác định hệ tọa độ mới với góc Euler (0.0, 0.0, -90.0) và vectơ tịnh tiến (-0.365, 0.7173, 0.0338).\n\nTiếp theo, tạo bản phác thảo trên mặt phẳng được xác định bởi hệ tọa độ mới. Bản phác thảo bao gồm bốn mặt, mỗi mặt có một hoặc nhiều vòng lặp.\n\nĐối với Mặt 1, tạo Vòng lặp 1 với các đường thẳng và cung được chỉ định, tiến hành ngược chiều kim đồng hồ từ điểm bắt đầu. Đối với Mặt 2, tạo Vòng lặp 1 với các đường thẳng và cung được chỉ định, tiến hành ngược chiều kim đồng hồ từ điểm bắt đầu.\n\nTương tự, tạo các vòng lặp cho Mặt 3 và Mặt 4.\n\nSau khi tạo bản phác thảo, tiếp tục đùn bản phác thảo với độ sâu 0.7173 về phía pháp tuyến và 0.0 ngược với pháp tuyến. Phóng to bản phác thảo theo hệ số 0.6737 và sử dụng \"NewBodyFeatureOperation\" cho bản phác thảo.\n\nPhần kết quả là một lăng trụ chữ nhật ba chiều có lỗ hình trụ ở giữa. Lỗ lớn hơn một chút so với chiều rộng của lăng trụ, và lăng trụ được đặt trên một mặt phẳng. Chiều dài, chiều rộng và chiều cao của phần lần lượt là 0.6737, 0.7173 và 0.6737 đơn vị.",
  "Tạo phần đầu tiên của mô hình CAD, một lăng trụ chữ nhật đơn giản có mặt trên và dưới phẳng. Bắt đầu bằng cách thiết lập hệ tọa độ mới với các góc Euler (0.0, 0.0, 0.0) và vectơ tịnh tiến (0.0, 0.0, 0.0).\n\nTiếp theo, tạo bản phác thảo trên mặt 1 của hệ tọa độ như sau:\n\n- Tạo đường 1 từ (0.0, 0.0) đến (0.375, 0.0)\n- Tạo đường 2 từ (0.375, 0.0) đến (0.75, 0.0)\n- Tạo đường 3 từ (0.75, 0.0) đến (0.75, 0.0417)\n- Tạo đường 4 từ (0.75, 0.0417) đến (0.3958, 0.0417)\n- Tạo đường 5 từ (0.3958, 0.0417) đến (0.3958, 0.375)\n- Tạo đường 6 từ (0.3958, 0.375) đến (0.375, 0.375)\n- Tạo đường 7 từ (0.375, 0.375) đến (0.3542, 0.375)\n- Tạo đường 8 từ (0.3542, 0.375) đến (0.3542, 0.0417)\n- Tạo đường 9 từ (0.3542, 0.0417) đến (0.0, 0.0417)\n- Tạo đường 10 từ (0.0, 0.0417) đến (0.0, 0.0)\n\nBây giờ, phóng to bản phác thảo theo hệ số 0.75 và đùn nó dọc theo hướng pháp tuyến với độ sâu 0.0417. Đảm bảo rằng việc đùn tạo ra một khối rắn mới.\n\nPhần đầu tiên của mô hình CAD có các kích thước sau: Chiều dài: 0.75, Chiều rộng: 0.75, Chiều cao: 0.0417 (bao gồm độ sâu đùn).\n\nTạo phần thứ hai của mô hình CAD, một lăng trụ chữ nhật nhỏ hơn có mặt trên và dưới phẳng. Bắt đầu bằng cách thiết lập hệ tọa độ mới với các góc Euler (0.0, 0.0, 0.0) và vectơ tịnh tiến (0.3542, 0.2917, 0.0417).\n\nTiếp theo, tạo bản phác thảo trên mặt 1 của hệ tọa độ như sau:\n\n- Tạo đường 1 từ (0.0, 0.0) đến (0.0417, 0.0)\n- Tạo đường 2 từ (0.0417, 0.0) đến (0.0417, 0.0417)\n- Tạo đường 3 từ (0.0417, 0.0417) đến (0.0, 0.0417)\n- Tạo đường 4 từ (0.0, 0.0417) đến (0.0, 0.0)\n\nBây giờ, phóng to bản phác thảo theo hệ số 0.0417 và đùn nó dọc theo hướng pháp tuyến với độ sâu 0.0417. Đảm bảo rằng thao tác đùn này được đặt là \"Join\".\n\nPhần thứ hai của mô hình CAD có các kích thước sau: Chiều dài: 0.0417, Chiều rộng: 0.0417, Chiều cao: 0.0417 (bao gồm độ sâu đùn).",
  "Tạo phần đầu tiên của mô hình CAD, một lăng trụ chữ nhật ba chiều có mặt trên và mặt dưới phẳng. Bắt đầu bằng cách thiết lập một hệ tọa độ mới với các góc Euler [0.0, 0.0, 0.0] độ và vectơ tịnh tiến [0.0, 0.0, 0.0938].\n\nTiếp theo, tạo bản phác thảo trên mặt phẳng X-Y của hệ tọa độ và vẽ một hình chữ nhật với bốn đường thẳng. Đường thẳng đầu tiên bắt đầu tại [0.0, 0.0] và kết thúc tại [0.75, 0.0]. Đường thẳng thứ hai bắt đầu tại [0.75, 0.0] và kết thúc tại [0.75, 0.375]. Đường thẳng thứ ba bắt đầu tại [0.75, 0.375] và kết thúc tại [0.0, 0.375]. Đường thẳng thứ tư bắt đầu tại [0.0, 0.375] và kết thúc tại điểm bắt đầu của đường thẳng đầu tiên, [0.0, 0.0].\n\nĐóng vòng lặp bằng cách nối điểm cuối của Đường 4 với điểm bắt đầu của Đường 1. Phóng to bản phác thảo theo hệ số 0.75.\n\nBiến đổi bản phác thảo 2D thành bản phác thảo 3D sử dụng hệ tọa độ đã xác định. Đùn bản phác thảo 3D 0.0469 đơn vị theo cả hướng dương và âm của trục Z, tạo ra một lăng trụ chữ nhật ba chiều có mặt trên và mặt dưới phẳng và chiều cao 0.09375 đơn vị.\n\nPhần đầu tiên của mô hình CAD có các kích thước sau: chiều dài 0.75 đơn vị, chiều rộng 0.75 đơn vị và chiều cao 0.09375 đơn vị (bao gồm độ sâu đùn).",
  "Tạo phần đầu tiên của mô hình CAD bằng cách xây dựng hình dạng hình học ba chiều có đáy hình chữ nhật và đỉnh hình tam giác, được nối bằng một đường thẳng. Bắt đầu bằng cách thiết lập hệ tọa độ mới với góc Euler (-90.0, 0.0, -90.0) và vectơ tịnh tiến (0.0, 0.0, 0.0).\n\nTiếp theo, tạo bản phác thảo 2D trên mặt phẳng X-Y của hệ tọa độ, bao gồm hai mặt: Mặt 1 (Vòng lặp 1, Đường 1-5) và Mặt 2 (Vòng lặp 1, Đường 1-3). Phóng to và đùn bản phác thảo dọc theo hướng pháp tuyến với độ sâu 0.375, tạo ra phần đầu tiên của mô hình CAD. Thực hiện thao tác tạo khối rắn mới.\n\nPhần này có các kích thước sau:\n\n- Chiều dài: 0.375\n- Chiều rộng: 0.375\n- Chiều cao: 0.375 (bao gồm độ sâu đùn)\n\nTạo phần thứ hai của mô hình CAD bằng cách xây dựng một lăng trụ chữ nhật có mặt trên và mặt dưới phẳng, trong đó chiều cao xấp xỉ gấp đôi chiều rộng, và chiều dài cạnh ngắn hơn khoảng một nửa chiều dài cạnh dài hơn. Thiết lập hệ tọa độ mới với góc Euler (-90.0, 0.0, -90.0) và vectơ tịnh tiến (0.0, 0.125, 0.0).\n\nTạo bản phác thảo 2D mới trên mặt phẳng X-Y của hệ tọa độ mới với Mặt 1 (Vòng lặp 1, Đường 1-3). Phóng to và đùn bản phác thảo dọc theo hướng pháp tuyến với độ sâu 0.75, sau đó nối khối rắn mới với khối hiện có.\n\nPhần thứ hai của mô hình CAD có các kích thước sau:\n\n- Chiều dài: 0.75\n- Chiều rộng: 0.25\n- Chiều cao: 0.25 (bao gồm độ sâu đùn)",
  "Tạo phần đầu tiên của mô hình CAD, một giá đỡ kim loại hình chữ nhật với hai lỗ ở mặt trên, bằng cách làm theo các hướng dẫn được cung cấp. Bắt đầu bằng cách thiết lập hệ tọa độ mới với góc Euler (0.0, 0.0, 0.0) và vectơ tịnh tiến (0.0, 0.0, 0.0833).\n\nTiếp theo, tạo bản phác thảo 2D trên mặt phẳng X-Y của hệ tọa độ. Bản phác thảo bao gồm bốn vòng lặp (Vòng lặp 1, 2, 3 và 4) trên một mặt phẳng chung.\n\nVòng lặp 1 được tạo bởi một chuỗi 4 đường thẳng:\n\n1. Đường 1: [0.0, 0.0] đến [0.75, 0.0]\n2. Đường 2: [0.75, 0.0] đến [0.75, 0.2]\n3. Đường 3: [0.75, 0.2] đến [0.0, 0.2]\n4. Đường 4: [0.0, 0.2] đến [0.0, 0.0]\n\nVòng lặp 2, 3 và 4 dành cho các lỗ với hình tròn bên trong. Tạo thêm 3 vòng lặp khác để hoàn thành bản phác thảo 2D.\n\nĐối với Mặt phác thảo 2, vẽ một hình tròn có tâm tại [0.125, 0.1] với bán kính 0.0542.\n\nĐối với Mặt phác thảo 3, vẽ một hình tròn có tâm tại [0.375, 0.1] với bán kính 0.0542.\n\nĐối với Mặt phác thảo 4, vẽ một hình tròn có tâm tại [0.625, 0.1] với bán kính 0.0542.\n\nBây giờ, phóng to bản phác thảo 2D theo hệ số 0.75.\n\nĐể tạo mô hình 3D, làm theo các bước sau:\n\n1. Tạo bản phác thảo 3D bằng cách đặt `extrude_depth_towards_normal` thành 0.0, `extrude_depth_opposite_normal` thành 0.0833 và `sketch_scale` thành 0.75.\n2. Áp dụng \"New Body Feature Operation\" để tạo khối rắn mới.\n\nMô hình 3D đã hoàn thành (Phần 1) là một giá đỡ kim loại hình chữ nhật có hai lỗ ở mặt trên. Phần 1 có chiều cao 0.0833, chiều rộng 0.75 và chiều dài 0.75 đơn vị."
]

# %%
for x in range(20):
    lada[x]['input_vi'] = trans[x]

# %%
for data in range(len(new)):
    if new[data]['input_vi'] == '':
        for x in lada:
            if new[data]['uid'] == x['uid']:
                new[data]['input_vi'] = x['input_vi']

# %%
not_none_data = []
none_data = []
indexs = {}
for data in data_part3:
    indexs[data['uid']] = data['input_vi']
    if data['input_vi'] is None:
        none_data.append(data)
    else:
        not_none_data.append(data)
        
for data in data_part2:
    indexs[data['uid']] = data['input_vi']
    if data['input_vi'] is None:
        none_data.append(data)
    else:
        not_none_data.append(data)

# %%
save = {
    'uid': [],
    'input': [],
    'input_vi':[],
    'output':[],
    'instruction':[]
}

# %%
for data in not_none_data:
    for key, value in data.items():
        save[key].append(value)

# %%
save['input_vi'] = [' '.join(v) if type(v) == list else v for v in save['input_vi']]

# %%
for key, value in save.items():
    for v in value:
        if  type(v) != str:
            print(type(v))
    # print(f"{key}: {[type(v) for v in value if type(v) != str]}")

# %%
data_main = Dataset.from_dict(save)

# %%
data_main
# Out:
# Dataset({
#     features: ['uid', 'input', 'input_vi', 'output', 'instruction'],
#     num_rows: 61132
# })

# %%
def read_jsonl(path):
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)

    return data

# %%
data1 = read_jsonl("./done_p23/translation_0.json")

# %%
data1 = Dataset.from_list(data1)

# %%
from datasets import concatenate_datasets
final = concatenate_datasets([data_main, data1])

# %%
def read_jsonl(filepath):
    data = []
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line))
    return data
final = read_jsonl('final_p23.jsonl')

# %%
final = Dataset.from_list(final)
final
# Out:
# Dataset({
#     features: ['uid', 'input', 'input_vi', 'output', 'instruction'],
#     num_rows: 115681
# })

# %%
from datasets import concatenate_datasets

final = concatenate_datasets([new, final])
final
# Out:
# Dataset({
#     features: ['uid', 'input', 'input_vi', 'output', 'instruction'],
#     num_rows: 173521
# })

# %%
import pandas as pd
final.to_pandas().to_json("final_done.jsonl", orient="records", lines=True, force_ascii=False)

# %%
save_result(final,

# %%
data_main.save_to_disk('translated_main')
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/104389 [00:00<?, ? examples/s]

# %%
57840*3+1
# Out:
# 173521

# %%
cc = 0
failed = []
length = []
hehe = []
huhu = []
for data in final:
    length.append(len(data['input'].split(' ')))
    # hehe.append(data['input'].count('.'))
    # huhu.append(len(data['input'].split(' '))/((data['input'].count('.'))+0.00001))
    hehe.append((data['input'], data['uid']))
    # if data['input'][-1] == '.':
    #     cc += 1
    # else:
    #     failed.append(data)
# cc

# %%
for data in final:
    if data['uid'] == '0038/00388507':
        print(data)
        break
# Out:
# {'uid': '0038/00388507', 'input': 'Construct the first part of the CAD model, a rectangular prism with a flat top and bottom, and a curved side. Begin by creating a new coordinate system with Euler angles of (0.0, 0.0, 0.0) and a translation vector of (0.01, 0.01, 0.0).\n\nSketch Face 1 of the CAD model, a rectangle with the following lines:\n\n- Line 1: Start Point (0.0, 0.0), End Point (0.73, 0.0)\n- Line 2: Start Point (0.73, 0.0), End Point (0.73, 0.35)\n- Line 3: Start Point (0.73, 0.35), End Point (0.0, 0.35)\n- Line 4: Start Point (0.0, 0.35), End Point (0.0, 0.0)', 'input_vi': 'Xây dựng phần đầu tiên của mô hình CAD, một lăng kính chữ nhật với mặt trên và mặt dưới phẳng, và một mặt cong. Bắt đầu bằng cách tạo một hệ tọa độ mới với các góc Euler là (0.0, 0.0, 0.0) và một vectơ tịnh tiến là (0.01, 0.01, 0.0).\n\nPhác thảo Mặt 1 của mô hình CAD, một hình chữ nhật với các đường thẳng sau:\n\n- Đường 1: Điểm bắt đầu (0.0, 0.0), Điểm kết thúc (0.73, 0.0)\n- Đường 2: Điểm bắt đầu (0
# ...

# %%
top10 = sorted(hehe, key=lambda x: len(x[0]))[:500]
top10
# Out:
# [('**', '0023/00236015'),
#  ('Create `', '0024/00242036'),
#  ('Construct `', '0049/00493136'),
#  ('Construct an external prism,', '0042/00425083'),
#  ('The first part of the CAD model,', '0023/00238102'),
#  ('Construct the CAD model in two parts.', '0080/00802259'),
#  ('The CAD model consists of four parts.', '0095/00950042'),
#  ('The CAD model consists of three parts.', '0005/00054512'),
#  ('The final shape consists of five parts.', '0082/00822603'),
#  ('Construct the CAD model in three parts.', '0063/00630146'),
#  ('Create the first part of the CAD model, a', '0000/00005107'),
#  ('The first part of the CAD model, referred to as', '0008/00085991'),
#  ('Construct a three-dimensional rectangular prism (', '0068/00682065'),
#  ('Create a new coordinate system with Euler angles of', '0069/00693934'),
#  ('Construct the donut-shaped final shape in three parts.', '0006/00068836'),
#  ('Create a new coordinate system with euler angles set to', '0075/00757441'),
# ...

# %%
import numpy as np

lengths = hehe # danh sách độ dài chuỗi
q1 = np.percentile(lengths, 25)
q3 = np.percentile(lengths, 75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outliers = [l for l in lengths if l < lower_bound ]
print("Outlier lengths:", outliers)
# Out:
# Outlier lengths: []

# %%
sum(huhu)/len(huhu)
# Out:
# 151.89225011296244

# %%
sorted(hehe)[200:210]
# Out:
# [2.2777776804368512,
#  2.278480724242946,
#  2.2784808684505777,
#  2.279069590769799,
#  2.279411429498319,
#  2.2799998176000145,
#  2.280373618656671,
#  2.2820506969100776,
#  2.284615208875753,
#  2.285714104308404]
