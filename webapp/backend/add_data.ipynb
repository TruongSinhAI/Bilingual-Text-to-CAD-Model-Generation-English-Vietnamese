# %%
from semantic_cache_chroma import ChromaSemanticCache

sem_cache = ChromaSemanticCache()
# Out:
# ✅ Initialized Chroma cache at ./chroma_cache with collection 'semantic_cache'

# %%
sem_cache.collection.delete(ids=["id--5479383660996601244"])

# %%
input = '''Part 1 — Construct a rounded rectangular frame (new body) Create a new coordinate system: Euler Angles: [0.0, 0.0, 0.0] Translation Vector: [0.0, 0.0, 0.4139] On the X–Y plane (face_1), draw Loop 1 (outer rounded rectangle): Arc 1: Start [0.0, 0.1077], Mid [0.0316, 0.0316], End [0.1077, 0.0] Line 1: [0.1077, 0.0] → [0.6423, 0.0] Arc 2: Start [0.6423, 0.0], Mid [0.7184, 0.0316], End [0.75, 0.1077] Line 2: [0.75, 0.1077] → [0.75, 0.6423] Arc 3: Start [0.75, 0.6423], Mid [0.7184, 0.7184], End [0.6423, 0.75] Line 3: [0.6423, 0.75] → [0.1077, 0.75] Arc 4: Start [0.1077, 0.75], Mid [0.0316, 0.7184], End [0.0, 0.6423] Line 4: [0.0, 0.6423] → [0.0, 0.1077] On face_1, draw Loop 2 (inner rounded rectangle): Arc 1: Start [0.0082, 0.1105], Mid [0.0381, 0.0381], End [0.1105, 0.0082] Line 1: [0.1105, 0.0082] → [0.6395, 0.0082] Arc 2: Start [0.6395, 0.0082], Mid [0.7119, 0.0381], End [0.7418, 0.1105] Line 2: [0.7418, 0.1105] → [0.7418, 0.6395] Arc 3: Start [0.7418, 0.6395], Mid [0.7119, 0.7119], End [0.6395, 0.7418] Line 3: [0.6395, 0.7418] → [0.1105, 0.7418] Arc 4: Start [0.1105, 0.7418], Mid [0.0381, 0.7119], End [0.0082, 0.6395] Line 4: [0.0082, 0.6395] → [0.0082, 0.1105] Scale the sketch by 0.75 and transform to 3D. Extrude with extrude_depth_towards_normal = 0.0068, extrude_depth_opposite_normal = 0.0. Operation: NewBodyFeatureOperation. Part 2 — Extend the shell (join to existing body) Use the same coordinate system as Part 1 (Euler [0,0,0], Translation [0,0,0.4139]). On face_1, repeat Loop 1 and Loop 2 exactly as in Part 1. On face_2, draw Loop 1 identical to Part 1’s Loop 2 (inner rounded rectangle): Arc 1: Start [0.0082, 0.1105], Mid [0.0381, 0.0381], End [0.1105, 0.0082] Line 1: [0.1105, 0.0082] → [0.6395, 0.0082] Arc 2: Start [0.6395, 0.0082], Mid [0.7119, 0.0381], End [0.7418, 0.1105] Line 2: [0.7418, 0.1105] → [0.7418, 0.6395] Arc 3: Start [0.7418, 0.6395], Mid [0.7119, 0.7119], End [0.6395, 0.7418] Line 3: [0.6395, 0.7418] → [0.1105, 0.7418] Arc 4: Start [0.1105, 0.7418], Mid [0.0381, 0.7119], End [0.0082, 0.6395] Line 4: [0.0082, 0.6395] → [0.0082, 0.1105] Scale the sketch by 0.75 and transform to 3D. Extrude with extrude_depth_towards_normal = 0.0, extrude_depth_opposite_normal = 0.4091 along the Z-axis. Operation: JoinFeatureOperation (adds material to the existing body). Part 3 — Cut the inner cavity (remove material) Create a new coordinate system: Euler Angles: [0.0, 0.0, 0.0] Translation Vector: [0.0082, 0.0082, 0.4139] On face_1, draw Loop 1 (inner rounded rectangle): Arc 1: Start [0.0, 0.1023], Mid [0.03, 0.03], End [0.1023, 0.0] Line 1: [0.1023, 0.0] → [0.6314, 0.0] Arc 2: Start [0.6314, 0.0], Mid [0.7037, 0.03], End [0.7336, 0.1023] Line 2: [0.7336, 0.1023] → [0.7336, 0.6314] Arc 3: Start [0.7336, 0.6314], Mid [0.7037, 0.7037], End [0.6314, 0.7336] Line 3: [0.6314, 0.7336] → [0.1023, 0.7336] Arc 4: Start [0.1023, 0.7336], Mid [0.03, 0.7037], End [0.0, 0.6314] Line 4: [0.0, 0.6314] → [0.0, 0.1023] Scale the sketch by 0.7336 and transform to 3D. Extrude with extrude_depth_towards_normal = 0.0, extrude_depth_opposite_normal = 0.4091. Operation: CutFeatureOperation (removes material to form the cavity).'''

# %%
out = '''{"parts": {"part_1": {"coordinate_system": {"Euler Angles": [0.0, 0.0, -90.0], "Translation Vector": [0.0, 0.0073, 0.0]}, "sketch": {"face_1": {"loop_1": {"line_1": {"Start Point": [0.0, 0.0], "End Point": [0.75, 0.0]}, "line_2": {"Start Point": [0.75, 0.0], "End Point": [0.75, 0.2183]}, "line_3": {"Start Point": [0.75, 0.2183], "End Point": [0.0, 0.2183]}, "line_4": {"Start Point": [0.0, 0.2183], "End Point": [0.0, 0.0]}}}}, "extrusion": {"extrude_depth_towards_normal": 0.0073, "extrude_depth_opposite_normal": 0.0, "sketch_scale": 0.75, "operation": "NewBodyFeatureOperation"}}, "part_2": {"coordinate_system": {"Euler Angles": [180.0, 0.0, -90.0], "Translation Vector": [0.75, 0.0073, 0.1946]}, "sketch": {"face_1": {"loop_1": {"line_1": {"Start Point": [0.0, 0.0], "End Point": [0.75, 0.0]}, "line_2": {"Start Point": [0.75, 0.0], "End Point": [0.75, 0.0237]}, "line_3": {"Start Point": [0.75, 0.0237], "End Point": [0.0, 0.0237]}, "line_4": {"Start Point": [0.0, 0.0237], "End Point": [0.0, 0.0]}}}}, "extrusion": {"extrude_depth_towards_normal": 0.0121, "extrude_depth_opposite_normal": 0.0, "sketch_scale": 0.75, "operation": "JoinFeatureOperation"}}, "part_3": {"coordinate_system": {"Euler Angles": [180.0, 0.0, -90.0], "Translation Vector": [0.75, 0.0073, 0.0]}, "sketch": {"face_1": {"loop_1": {"line_1": {"Start Point": [0.0, 0.0], "End Point": [0.75, 0.0]}, "line_2": {"Start Point": [0.75, 0.0], "End Point": [0.75, 0.025]}, "line_3": {"Start Point": [0.75, 0.025], "End Point": [0.0, 0.025]}, "line_4": {"Start Point": [0.0, 0.025], "End Point": [0.0, 0.0]}}}}, "extrusion": {"extrude_depth_towards_normal": 0.0121, "extrude_depth_opposite_normal": 0.0, "sketch_scale": 0.75, "operation": "JoinFeatureOperation"}}, "part_4": {"coordinate_system": {"Euler Angles": [180.0, 0.0, -90.0], "Translation Vector": [0.75, 0.0073, 0.025]}, "sketch": {"face_1": {"loop_1": {"line_1": {"Start Point": [0.0, 0.0], "End Point": [0.0245, 0.0]}, "line_2": {"Start Point": [0.0245, 0.0], "End Point": [0.0245, 0.1696]}, "line_3": {"Start Point": [0.0245, 0.1696], "End Point": [0.0, 0.1696]}, "line_4": {"Start Point": [0.0, 0.1696], "End Point": [0.0, 0.0]}}}}, "extrusion": {"extrude_depth_towards_normal": 0.0128, "extrude_depth_opposite_normal": 0.0, "sketch_scale": 0.1696, "operation": "JoinFeatureOperation"}}, "part_5": {"coordinate_system": {"Euler Angles": [180.0, 0.0, -90.0], "Translation Vector": [0.0263, 0.0073, 0.025]}, "sketch": {"face_1": {"loop_1": {"line_1": {"Start Point": [0.0, 0.0], "End Point": [0.0263, 0.0]}, "line_2": {"Start Point": [0.0263, 0.0], "End Point": [0.0263, 0.1696]}, "line_3": {"Start Point": [0.0263, 0.1696], "End Point": [0.0, 0.1696]}, "line_4": {"Start Point": [0.0, 0.1696], "End Point": [0.0, 0.0]}}}}, "extrusion": {"extrude_depth_towards_normal": 0.0128, "extrude_depth_opposite_normal": 0.0, "sketch_scale": 0.1696, "operation": "JoinFeatureOperation"}}, "part_6": {"coordinate_system": {"Euler Angles": [180.0, 0.0, -90.0], "Translation Vector": [0.6124, 0.0073, 0.025]}, "sketch": {"face_1": {"loop_1": {"line_1": {"Start Point": [0.0, 0.0], "End Point": [0.0314, 0.0]}, "line_2": {"Start Point": [0.0314, 0.0], "End Point": [0.0314, 0.1696]}, "line_3": {"Start Point": [0.0314, 0.1696], "End Point": [0.0, 0.1696]}, "line_4": {"Start Point": [0.0, 0.1696], "End Point": [0.0, 0.0]}}}}, "extrusion": {"extrude_depth_towards_normal": 0.0128, "extrude_depth_opposite_normal": 0.0, "sketch_scale": 0.1696, "operation": "JoinFeatureOperation"}}, "part_7": {"coordinate_system": {"Euler Angles": [180.0, 0.0, -90.0], "Translation Vector": [0.4691, 0.0073, 0.025]}, "sketch": {"face_1": {"loop_1": {"line_1": {"Start Point": [0.0, 0.0], "End Point": [0.0314, 0.0]}, "line_2": {"Start Point": [0.0314, 0.0], "End Point": [0.0314, 0.1696]}, "line_3": {"Start Point": [0.0314, 0.1696], "End Point": [0.0, 0.1696]}, "line_4": {"Start Point": [0.0, 0.1696], "End Point": [0.0, 0.0]}}}}, "extrusion": {"extrude_depth_towards_normal": 0.0128, "extrude_depth_opposite_normal": 0.0, "sketch_scale": 0.1696, "operation": "JoinFeatureOperation"}}, "part_8": {"coordinate_system": {"Euler Angles": [180.0, 0.0, -90.0], "Translation Vector": [0.3273, 0.0073, 0.025]}, "sketch": {"face_1": {"loop_1": {"line_1": {"Start Point": [0.0, 0.0], "End Point": [0.0377, 0.0]}, "line_2": {"Start Point": [0.0377, 0.0], "End Point": [0.0377, 0.1696]}, "line_3": {"Start Point": [0.0377, 0.1696], "End Point": [0.0, 0.1696]}, "line_4": {"Start Point": [0.0, 0.1696], "End Point": [0.0, 0.0]}}}}, "extrusion": {"extrude_depth_towards_normal": 0.0128, "extrude_depth_opposite_normal": 0.0, "sketch_scale": 0.1696, "operation": "JoinFeatureOperation"}}, "part_9": {"coordinate_system": {"Euler Angles": [180.0, 0.0, -90.0], "Translation Vector": [0.1799, 0.0073, 0.025]}, "sketch": {"face_1": {"loop_1": {"line_1": {"Start Point": [0.0, 0.0], "End Point": [0.0377, 0.0]}, "line_2": {"Start Point": [0.0377, 0.0], "End Point": [0.0377, 0.1696]}, "line_3": {"Start Point": [0.0377, 0.1696], "End Point": [0.0, 0.1696]}, "line_4": {"Start Point": [0.0, 0.1696], "End Point": [0.0, 0.0]}}}}, "extrusion": {"extrude_depth_towards_normal": 0.0128, "extrude_depth_opposite_normal": 0.0, "sketch_scale": 0.1696, "operation": "JoinFeatureOperation"}}}}'''

# %%
sem_cache.add(input, out)
# Out:
# 💾 [Cache] Added to ChromaDB.

# %%
sem_cache.find(input)
# Out:
# 🔍 [Cache] Raw results: {'ids': [['id--7146891483103297493']], 'embeddings': None, 'documents': [['Part 1 — Construct a rounded rectangular frame (new body) Create a new coordinate system: Euler Angles: [0.0, 0.0, 0.0] Translation Vector: [0.0, 0.0, 0.4139] On the X–Y plane (face_1), draw Loop 1 (outer rounded rectangle): Arc 1: Start [0.0, 0.1077], Mid [0.0316, 0.0316], End [0.1077, 0.0] Line 1: [0.1077, 0.0] → [0.6423, 0.0] Arc 2: Start [0.6423, 0.0], Mid [0.7184, 0.0316], End [0.75, 0.1077] Line 2: [0.75, 0.1077] → [0.75, 0.6423] Arc 3: Start [0.75, 0.6423], Mid [0.7184, 0.7184], End [0.6423, 0.75] Line 3: [0.6423, 0.75] → [0.1077, 0.75] Arc 4: Start [0.1077, 0.75], Mid [0.0316, 0.7184], End [0.0, 0.6423] Line 4: [0.0, 0.6423] → [0.0, 0.1077] On face_1, draw Loop 2 (inner rounded rectangle): Arc 1: Start [0.0082, 0.1105], Mid [0.0381, 0.0381], End [0.1105, 0.0082] Line 1: [0.1105, 0.0082] → [0.6395, 0.0082] Arc 2: Start [0.6395, 0.0082], Mid [0.7119, 0.0381], End [0.7418, 0.1105] L
# ...

# %%
'{"parts": {"part_1": {"coordinate_system": {"Euler Angles": [0.0, 0.0, 0.0], "Translation Vector": [0.1086, 0.0, 0.0]}, "sketch": {"face_1": {"loop_1": {"line_1": {"Start Point": [0.0, 0.0], "End Point": [0.5329, 0.0]}, "line_2": {"Start Point": [0.5329, 0.0], "End Point": [0.5329, 0.3553]}, "line_3": {"Start Point": [0.5329, 0.3553], "End Point": [0.0, 0.3553]}, "line_4": {"Start Point": [0.0, 0.3553], "End Point": [0.0, 0.0]}}}}, "extrusion": {"extrude_depth_towards_normal": 0.4342, "extrude_depth_opposite_normal": 0.0, "sketch_scale": 0.5329, "operation": "NewBodyFeatureOperation"}}, "part_2": {"coordinate_system": {"Euler Angles": [0.0, 0.0, -90.0], "Translation Vector": [0.174, 0.0, 0.148]}, "sketch": {"face_1": {"loop_1": {"line_1": {"Start Point": [0.0, 0.0], "End Point": [0.3947, 0.0]}, "line_2": {"Start Point": [0.3947, 0.0], "End Point": [0.3947, 0.2862]}, "line_3": {"Start Point": [0.3947, 0.2862], "End Point": [0.0, 0.2862]}, "line_4": {"Start Point": [0.0, 0.2862], "End Point": [0.0, 0.0]}}}}, "extrusion": {"extrude_depth_towards_normal": 0.0, "extrude_depth_opposite_normal": 0.3553, "sketch_scale": 0.3947, "operation": "CutFeatureOperation"}}, "part_3": {"coordinate_system": {"Euler Angles": [0.0, 0.0, 0.0], "Translation Vector": [0.6414, 0.0, 0.4342]}, "sketch": {"face_1": {"loop_1": {"line_1": {"Start Point": [0.0, 0.0], "End Point": [0.1086, 0.0]}, "line_2": {"Start Point": [0.1086, 0.0], "End Point": [0.1086, 0.3553]}, "line_3": {"Start Point": [0.1086, 0.3553], "End Point": [0.0, 0.3553]}, "line_4": {"Start Point": [0.0, 0.3553], "End Point": [0.0, 0.0]}}}}, "extrusion": {"extrude_depth_towards_normal": 0.0, "extrude_depth_opposite_normal": 0.0691, "sketch_scale": 0.3553, "operation": "JoinFeatureOperation"}}, "part_4": {"coordinate_system": {"Euler Angles": [0.0, 0.0, 0.0], "Translation Vector": [0.6809, 0.0847, 0.4342]}, "sketch": {"face_1": {"loop_1": {"line_1": {"Start Point": [0.0, 0.0], "End Point": [0.0691, 0.0]}, "line_2": {"Start Point": [0.0691, 0.0], "End Point": [0.0691, 0.1776]}, "line_3": {"Start Point": [0.0691, 0.1776], "End Point": [0.0, 0.1776]}, "line_4": {"Start Point": [0.0, 0.1776], "End Point": [0.0, 0.0]}}}}, "extrusion": {"extrude_depth_towards_normal": 0.0, "extrude_depth_opposite_normal": 0.0691, "sketch_scale": 0.1776, "operation": "CutFeatureOperation"}}, "part_5": {"coordinate_system": {"Euler Angles": [0.0, 0.0, 0.0], "Translation Vector": [0.0, 0.0, 0.4342]}, "sketch": {"face_1": {"loop_1": {"line_1": {"Start Point": [0.0, 0.0], "End Point": [0.1086, 0.0]}, "line_2": {"Start Point": [0.1086, 0.0], "End Point": [0.1086, 0.3553]}, "line_3": {"Start Point": [0.1086, 0.3553], "End Point": [0.0, 0.3553]}, "line_4": {"Start Point": [0.0, 0.3553], "End Point": [0.0, 0.0]}}}}, "extrusion": {"extrude_depth_towards_normal": 0.0, "extrude_depth_opposite_normal": 0.0691, "sketch_scale": 0.3553, "operation": "JoinFeatureOperation"}}, "part_6": {"coordinate_system": {"Euler Angles": [0.0, 0.0, 0.0], "Translation Vector": [0.0, 0.0847, 0.4342]}, "sketch": {"face_1": {"loop_1": {"line_1": {"Start Point": [0.0, 0.0], "End Point": [0.0691, 0.0]}, "line_2": {"Start Point": [0.0691, 0.0], "End Point": [0.0691, 0.1776]}, "line_3": {"Start Point": [0.0691, 0.1776], "End Point": [0.0, 0.1776]}, "line_4": {"Start Point": [0.0, 0.1776], "End Point": [0.0, 0.0]}}}}, "extrusion": {"extrude_depth_towards_normal": 0.0, "extrude_depth_opposite_normal": 0.0691, "sketch_scale": 0.1776, "operation": "CutFeatureOperation"}}, "part_7": {"coordinate_system": {"Euler Angles": [0.0, 0.0, 0.0], "Translation Vector": [0.2217, 0.0302, 0.148]}, "sketch": {"face_1": {"loop_1": {"circle_1": {"Center": [0.148, 0.148], "Radius": 0.148}}}}, "extrusion": {"extrude_depth_towards_normal": 0.2171, "extrude_depth_opposite_normal": 0.0, "sketch_scale": 0.2961, "operation": "JoinFeatureOperation"}}, "part_8": {"coordinate_system": {"Euler Angles": [0.0, 0.0, 0.0], "Translation Vector": [0.2711, 0.0796, 0.3651]}, "sketch": {"face_1": {"loop_1": {"circle_1": {"Center": [0.0987, 0.0987], "Radius": 0.0987}}}}, "extrusion": {"extrude_depth_towards_normal": 0.0, "extrude_depth_opposite_normal": 0.3947, "sketch_scale": 0.1974, "operation": "CutFeatureOperation"}}, "part_9": {"coordinate_system": {"Euler Angles": [0.0, 0.0, 0.0], "Translation Vector": [0.3207, 0.0302, 0.3651]}, "sketch": {"face_1": {"loop_1": {"arc_1": {"Start Point": [0.0, 0.0084], "Mid Point": [0.0494, 0.0], "End Point": [0.0987, 0.0086]}, "line_1": {"Start Point": [0.0987, 0.0086], "End Point": [0.0987, 0.0628]}, "arc_2": {"Start Point": [0.0987, 0.0628], "Mid Point": [0.0494, 0.0493], "End Point": [0.0, 0.0624]}, "line_2": {"Start Point": [0.0, 0.0624], "End Point": [0.0, 0.0084]}}}, "face_2": {"loop_1": {"arc_1": {"Start Point": [0.0, 0.2337], "Mid Point": [0.0494, 0.2467], "End Point": [0.0987, 0.2333]}, "line_1": {"Start Point": [0.0987, 0.2333], "End Point": [0.0987, 0.2875]}, "arc_2": {"Start Point": [0.0987, 0.2875], "Mid Point": [0.0494, 0.2961], "End Point": [0.0, 0.2877]}, "line_2": {"Start Point": [0.0, 0.2877], "End Point": [0.0, 0.2337]}}}}, "extrusion": {"extrude_depth_towards_normal": 0.0, "extrude_depth_opposite_normal": 0.0691, "sketch_scale": 0.2961, "operation": "CutFeatureOperation"}}}}'.replace('"',"'")
# Out:
# "{'parts': {'part_1': {'coordinate_system': {'Euler Angles': [0.0, 0.0, 0.0], 'Translation Vector': [0.1086, 0.0, 0.0]}, 'sketch': {'face_1': {'loop_1': {'line_1': {'Start Point': [0.0, 0.0], 'End Point': [0.5329, 0.0]}, 'line_2': {'Start Point': [0.5329, 0.0], 'End Point': [0.5329, 0.3553]}, 'line_3': {'Start Point': [0.5329, 0.3553], 'End Point': [0.0, 0.3553]}, 'line_4': {'Start Point': [0.0, 0.3553], 'End Point': [0.0, 0.0]}}}}, 'extrusion': {'extrude_depth_towards_normal': 0.4342, 'extrude_depth_opposite_normal': 0.0, 'sketch_scale': 0.5329, 'operation': 'NewBodyFeatureOperation'}}, 'part_2': {'coordinate_system': {'Euler Angles': [0.0, 0.0, -90.0], 'Translation Vector': [0.174, 0.0, 0.148]}, 'sketch': {'face_1': {'loop_1': {'line_1': {'Start Point': [0.0, 0.0], 'End Point': [0.3947, 0.0]}, 'line_2': {'Start Point': [0.3947, 0.0], 'End Point': [0.3947, 0.2862]}, 'line_3': {'Start Point': [0.3947, 0.2862], 'End Point': [0.0, 0.2862]}, 'line_4': {'Start Point': [0.0, 0.2862], 'End
# ...
